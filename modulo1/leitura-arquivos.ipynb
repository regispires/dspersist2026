# %%
import pandas as pd

# %%
df = pd.read_csv("contatos - Página1.csv")
df
# Out:
#     nome           email
# 0   João   joao@mail.com
# 1  Maria  maria@mail.com
# 2   José   jose@mail.com

# %%
df = pd.read_csv("contatos - Página1.tsv", sep='\t')
df
# Out:
#     nome           email
# 0   João   joao@mail.com
# 1  Maria  maria@mail.com
# 2   José   jose@mail.com

# %%
df = pd.read_excel("contatos.xlsx")
df
# Out:
#     nome           email
# 0   João   joao@mail.com
# 1  Maria  maria@mail.com
# 2   José   jose@mail.com
